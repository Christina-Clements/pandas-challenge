# %%
import pandas as pd
import numpy as np

data_file = "purchase_data.csv"
data_file_df = pd.read_csv(data_file)
data_file_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
total_players_df = data_file_df['SN'].value_counts()

total_players_df=len(total_players_df)
total_players_df
# Out:
# 576

# %%
total_players_df=pd.DataFrame({"Total Players": [total_players_df]})
total_players_df
# Out:
#    Total Players
# 0            576

# %%
unique_items_count = data_file_df["Item ID"].value_counts()
unique_items_count=len(unique_items_count)
# unique_items_count= pd.DataFrame({"Number of Unique Items": [unique_items_count]})
unique_items_count
# Out:
# 183

# %%
average_price = data_file_df["Price"].mean()
average_price =round(average_price,2)
# average_price=pd.DataFrame({"Average Purchase Price": [average_price]})
average_price
# Out:
# 3.05

# %%
Total_purchase_quantity = data_file_df["Purchase ID"].value_counts()
Total_purchase_quantity=len(Total_purchase_quantity)
# Total_purchase_quantity= pd.DataFrame({"Total Number of Purchases": [Total_purchase_quantity]})
Total_purchase_quantity
# Out:
# 780

# %%
Total_revenue = data_file_df["Price"].sum()
# Total_revenue= pd.DataFrame({"Total Revenue": [Total_revenue]})
Total_revenue
# Out:
# 2379.77

# %%
purchase_analysis = pd.DataFrame({"Number of Unique Items":[unique_items_count], 
                                  "Average Price in Dollars":[average_price],
                                  "Number of Purchases": [Total_purchase_quantity],
                                  "Total Revenue in Dollars": [Total_revenue]})
purchase_analysis= purchase_analysis.set_index("Number of Unique Items")
purchase_analysis
# Out:
#                         Average Price in Dollars  Number of Purchases  \
# Number of Unique Items
# 183                                         3.05                  780
#
#                         Total Revenue in Dollars
# Number of Unique Items
# 183                                      2379.77

# %%
gender_count = data_file_df["Gender"].value_counts()
gender_count=pd.DataFrame(gender_count)
gender_count=gender_count.stack().reset_index()
gender_count.columns=["Gender","Gender Delete", "Gender Count"]
gender_count=gender_count[["Gender", "Gender Count"]]
gender_count= gender_count.set_index("Gender")
gender_count
# Out:
#                        Gender Count
# Gender
# Male                            652
# Female                          113
# Other / Non-Disclosed            15

# %%
gender_percentage = (data_file_df["Gender"].value_counts())/780*100
gender_percentage= pd.DataFrame(round(gender_percentage,2))
gender_percentage=gender_percentage.stack().reset_index()
gender_percentage.columns=["Gender","Gender Delete", "Gender Percentage"]
gender_percentage=gender_percentage[["Gender", "Gender Percentage"]]
gender_percentage= gender_percentage.set_index("Gender")
gender_percentage
# Out:
#                        Gender Percentage
# Gender
# Male                               83.59
# Female                             14.49
# Other / Non-Disclosed               1.92

# %%
gender_analysis_df=pd.merge(gender_count, gender_percentage, on="Gender")

gender_analysis_df
# Out:
#                        Gender Count  Gender Percentage
# Gender
# Male                            652              83.59
# Female                          113              14.49
# Other / Non-Disclosed            15               1.92

# %%
gender_df = data_file_df.set_index("Gender")

gender_df= gender_df.groupby(["Gender"])
gender_df.count
# Out:
# <bound method DataFrameGroupBy.count of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x11176c410>>

# %%
gender_avg_price=gender_df["Price"].mean()
gender_avg_price= pd.DataFrame(round(gender_avg_price,2))
gender_avg_price= gender_avg_price.rename(columns={"Gender": "Gender", "Price": "Average Price"})
gender_avg_price
# Out:
#                        Average Price
# Gender
# Female                          3.20
# Male                            3.02
# Other / Non-Disclosed           3.35

# %%
gender_total_price=gender_df["Price"].sum()
gender_total_price=pd.DataFrame(gender_total_price)
gender_total_price= gender_total_price.rename(columns={"Gender": "Gender", "Price": "Total Price"})
gender_total_price
# Out:
#                        Total Price
# Gender
# Female                      361.94
# Male                       1967.64
# Other / Non-Disclosed        50.19

# %%
Avg_purchase_gender = gender_df["Purchase ID"].mean()
Avg_purchase_gender=pd.DataFrame(Avg_purchase_gender)
Avg_purchase_gender= Avg_purchase_gender.rename(columns={"Gender": "Gender","Purchase ID": "Average Total"})
Avg_purchase=(Avg_purchase_gender["Average Total"])/(gender_count["Gender Count"])
Avg_purchase_gender= round((Avg_purchase_gender["Average Total"])/(gender_count["Gender Count"]),2)
Avg_purchase_gender=pd.DataFrame(Avg_purchase_gender)
Avg_purchase_gender=Avg_purchase_gender.rename(columns={"Gender": "Gender", (0): "Average Purchase in Dollars"})

Avg_purchase_gender
# Out:
#                        Average Purchase in Dollars
# Gender
# Female                                        3.36
# Male                                          0.60
# Other / Non-Disclosed                        22.31

# %%
gender_purchase_analysis= pd.merge(gender_count, gender_avg_price, on="Gender")
gender_purchase_analysis=pd.merge(gender_purchase_analysis, gender_total_price, on="Gender")
gender_purchase_analysis=pd.merge(gender_purchase_analysis, Avg_purchase_gender, on="Gender")
gender_purchase_analysis=gender_purchase_analysis.rename(columns={"Gender": "Gender",(0): "Average Purchase"})
gender_purchase_analysis
# Out:
#                        Gender Count  Average Price  Total Price  \
# Gender
# Male                            652           3.02      1967.64
# Female                          113           3.20       361.94
# Other / Non-Disclosed            15           3.35        50.19
#
#                        Average Purchase in Dollars
# Gender
# Male                                          0.60
# Female                                        3.36
# Other / Non-Disclosed                        22.31

# %%
bins = [0, 9, 13, 18, 23, 28, 33, 38, 140]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

# %%
age_count_df= pd.cut(data_file_df["Age"], bins, labels=group_names)
age_count_df= pd.DataFrame(age_count_df)
age_count_df=age_count_df.groupby("Age")

age_count_df= pd.DataFrame(age_count_df["Age"].count())
age_count_df= age_count_df.rename(columns={"Age": "Age", "Age": "Player Count"})
age_count_df
# Out:
#        Player Count
# Age
# <10              23
# 10-14            26
# 15-19           115
# 20-24           321
# 25-29           155
# 30-34            77
# 35-39            44
# 40+              19

# %%
age_percentage_df= pd.cut(data_file_df["Age"], bins, labels=group_names)
age_percentage_df=pd.DataFrame(age_percentage_df)
age_percentage_df= age_percentage_df.groupby("Age")

age_percentage_df= pd.DataFrame(age_percentage_df["Age"].count())
age_percentage_df= age_percentage_df.rename(columns={"Age": "Age", "Age": "Player Count"})
age_percentage_df= round(age_percentage_df["Player Count"]/780*100,2)
age_percentage_df=pd.DataFrame(age_percentage_df)
age_percentage_df= age_percentage_df.rename(columns={"Age": "Age", "Player Count": "Percentage"})
age_percentage_df
# Out:
#        Percentage
# Age
# <10          2.95
# 10-14        3.33
# 15-19       14.74
# 20-24       41.15
# 25-29       19.87
# 30-34        9.87
# 35-39        5.64
# 40+          2.44

# %%
age_analysis_df=pd.merge(age_count_df, age_percentage_df, on="Age")

age_analysis_df
# Out:
#        Player Count  Percentage
# Age
# <10              23        2.95
# 10-14            26        3.33
# 15-19           115       14.74
# 20-24           321       41.15
# 25-29           155       19.87
# 30-34            77        9.87
# 35-39            44        5.64
# 40+              19        2.44

# %%
new_df=pd.cut(data_file_df["Age"], bins, labels=group_names).head()
data_file_df["Age"] = pd.cut(data_file_df["Age"], bins, labels=group_names)
new_df=data_file_df
new_df= new_df.groupby("Age")
new_df

# %%
avg_price_df=round((new_df[["Price"]].mean()),2)
avg_price_df=avg_price_df.rename(columns={"Age":"Age", "Price": "Average Price in Dollars"})
avg_price_df
# Out:
#        Average Price in Dollars
# Age
# <10                        3.35
# 10-14                      2.92
# 15-19                      3.04
# 20-24                      3.03
# 25-29                      3.02
# 30-34                      2.95
# 35-39                      3.33
# 40+                        3.24

# %%
age_purchase_analysis=pd.merge(age_count_df, avg_price_df, on="Age")

age_purchase_analysis
# Out:
#        Player Count  Average Price in Dollars
# Age
# <10              23                      3.35
# 10-14            26                      2.92
# 15-19           115                      3.04
# 20-24           321                      3.03
# 25-29           155                      3.02
# 30-34            77                      2.95
# 35-39            44                      3.33
# 40+              19                      3.24

# %%
total_price_df=round((new_df[["Price"]].sum()),2)

total_price_df= total_price_df.rename(columns={"Age": "Age", "Price": "Total Purchase Value"})
total_price_df
# Out:
#        Total Purchase Value
# Age
# <10                   77.13
# 10-14                 75.87
# 15-19                349.82
# 20-24                973.82
# 25-29                467.99
# 30-34                227.10
# 35-39                146.48
# 40+                   61.56

# %%
age_purchase_analysis=pd.merge(age_purchase_analysis, total_price_df, on="Age")

age_purchase_analysis
# Out:
#        Player Count  Average Price in Dollars  Total Purchase Value
# Age
# <10              23                      3.35                 77.13
# 10-14            26                      2.92                 75.87
# 15-19           115                      3.04                349.82
# 20-24           321                      3.03                973.82
# 25-29           155                      3.02                467.99
# 30-34            77                      2.95                227.10
# 35-39            44                      3.33                146.48
# 40+              19                      3.24                 61.56

# %%
Avg_purchase = new_df["Purchase ID"].mean()
Avg_purchase=pd.DataFrame(Avg_purchase)
Avg_purchase= Avg_purchase.rename(columns={"Age": "Age","Purchase ID": "Average Total"})
Avg_purchase=round(((Avg_purchase["Average Total"])/(age_count_df["Player Count"])),2)
Avg_purchase=pd.DataFrame(Avg_purchase)
Avg_purchase=Avg_purchase.rename(columns={"Age": "Age",(0): "Avg Total Purchase per Person"})

Avg_purchase
# Out:
#        Avg Total Purchase per Person
# Age
# <10                            18.92
# 10-14                          13.51
# 15-19                           3.54
# 20-24                           1.20
# 25-29                           2.53
# 30-34                           4.80
# 35-39                           8.63
# 40+                            22.73

# %%
age_purchase_analysis=pd.merge(age_purchase_analysis, Avg_purchase, on="Age")

# age_purchase_analysis= age_purchase_analysis.rename(columns={"Age": "Age", (0): "Average Purchase"})
age_purchase_analysis
# Out:
#        Player Count  Average Price in Dollars  Total Purchase Value  \
# Age
# <10              23                      3.35                 77.13
# 10-14            26                      2.92                 75.87
# 15-19           115                      3.04                349.82
# 20-24           321                      3.03                973.82
# 25-29           155                      3.02                467.99
# 30-34            77                      2.95                227.10
# 35-39            44                      3.33                146.48
# 40+              19                      3.24                 61.56
#
#        Avg Total Purchase per Person
# Age
# <10                            18.92
# 10-14                          13.51
# 15-19                           3.54
# 20-24                           1.20
# 25-29                           2.53
# 30-34                           4.80
# 35-39                           8.63
# 40+                            22.73

# %%
data_file_df.head()
# Out:
#    Purchase ID             SN    Age Gender  Item ID  \
# 0            0        Lisim78  20-24   Male      108
# 1            1    Lisovynya38    40+   Male      143
# 2            2     Ithergue48  25-29   Male       92
# 3            3  Chamassasya86  25-29   Male      100
# 4            4      Iskosia90  20-24   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
top_spenders_df= data_file_df.sort_values("SN")

top_spenders_df.head()
# Out:
#      Purchase ID            SN    Age  Gender  Item ID  \
# 467          467  Adairialis76  15-19    Male      123
# 142          142   Adastirin33  35-39  Female      175
# 388          388        Aeda94  15-19    Male      128
# 28            28        Aela59  20-24    Male      119
# 630          630     Aelaria33  20-24    Male      171
#
#                                      Item Name  Price
# 467                          Twilight's Carver   2.28
# 142                 Woeful Adamantite Claymore   4.48
# 388              Blazeguard, Reach of Eternity   4.91
# 28   Stormbringer, Dark Blade of Ending Misery   4.32
# 630                                    Scalpel   1.79

# %%
spenders_vcount_df = top_spenders_df["SN"].value_counts()
spenders_vcount_df= pd.DataFrame(spenders_vcount_df)

spenders_vcount_df= spenders_vcount_df.rename(columns={(0): "SN", "SN": "Purchase Count"})
spenders_vcount_df= spenders_vcount_df.reset_index()
spenders_vcount_df= spenders_vcount_df.rename(columns={("index"): "SN", "Purchase Count": "Purchase Count"})
spenders_vcount_df
# Out:
#                  SN  Purchase Count
# 0         Lisosia93               5
# 1            Iral74               4
# 2       Idastidru52               4
# 3          Phyali88               3
# 4      Saedaiphos46               3
# ..              ...             ...
# 571          Aeri84               1
# 572        Raisty38               1
# 573     Assjaskan56               1
# 574  Frichirranya75               1
# 575      Quilassa66               1
#
# [576 rows x 2 columns]

# %%
top_spenders_df= top_spenders_df.groupby(['SN'])
print(top_spenders_df)
top_spenders_df.count().head(10)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x111793090>
#               Purchase ID  Age  Gender  Item ID  Item Name  Price
# SN
# Adairialis76            1    1       1        1          1      1
# Adastirin33             1    1       1        1          1      1
# Aeda94                  1    1       1        1          1      1
# Aela59                  1    1       1        1          1      1
# Aelaria33               1    1       1        1          1      1
# Aelastirin39            2    2       2        2          2      2
# Aelidru27               1    1       1        1          1      1
# Aelin32                 3    3       3        3          3      3
# Aelly27                 2    2       2        2          2      2
# Aellynun67              1    1       1        1          1      1

# %%
spenders_avg_df=round((top_spenders_df["Price"].mean()),2)
spenders_avg_df= pd.DataFrame(spenders_avg_df)
spenders_avg_df= spenders_avg_df.rename(columns={"SN": "SN", "Price": "Average Purchase Price in Dollars"})
spenders_avg_df
# Out:
#                Average Purchase Price in Dollars
# SN
# Adairialis76                                2.28
# Adastirin33                                 4.48
# Aeda94                                      4.91
# Aela59                                      4.32
# Aelaria33                                   1.79
# ...                                          ...
# Yathecal82                                  2.07
# Yathedeu43                                  3.01
# Yoishirrala98                               4.58
# Zhisrisu83                                  3.94
# Zontibe81                                   2.68
#
# [576 rows x 1 columns]

# %%
top_spenders_analysis=pd.merge(spenders_vcount_df, spenders_avg_df, on="SN")

top_spenders_analysis
# Out:
#                  SN  Purchase Count  Average Purchase Price in Dollars
# 0         Lisosia93               5                               3.79
# 1            Iral74               4                               3.40
# 2       Idastidru52               4                               3.86
# 3          Phyali88               3                               3.43
# 4      Saedaiphos46               3                               2.94
# ..              ...             ...                                ...
# 571          Aeri84               1                               1.61
# 572        Raisty38               1                               3.27
# 573     Assjaskan56               1                               2.96
# 574  Frichirranya75               1                               4.23
# 575      Quilassa66               1                               4.23
#
# [576 rows x 3 columns]

# %%
spenders_total_df=top_spenders_df["Price"].sum()
spenders_total_df= pd.DataFrame(spenders_total_df)
spenders_total_df= spenders_total_df.rename(columns={"SN": "SN", "Price": "Total Purchase Value in Dollars"})
spenders_total_df
# Out:
#                Total Purchase Value in Dollars
# SN
# Adairialis76                              2.28
# Adastirin33                               4.48
# Aeda94                                    4.91
# Aela59                                    4.32
# Aelaria33                                 1.79
# ...                                        ...
# Yathecal82                                6.22
# Yathedeu43                                6.02
# Yoishirrala98                             4.58
# Zhisrisu83                                7.89
# Zontibe81                                 8.03
#
# [576 rows x 1 columns]

# %%
top_spenders_analysis=pd.merge(top_spenders_analysis, spenders_total_df, on="SN")

top_spenders_analysis=top_spenders_analysis.set_index("SN")
top_spenders_analysis
# Out:
#                 Purchase Count  Average Purchase Price in Dollars  \
# SN
# Lisosia93                    5                           3.792000
# Iral74                       4                           3.405000
# Idastidru52                  4                           3.862500
# Phyali88                     3                           3.433333
# Saedaiphos46                 3                           2.943333
# ...                        ...                                ...
# Aeri84                       1                           1.610000
# Raisty38                     1                           3.270000
# Assjaskan56                  1                           2.960000
# Frichirranya75               1                           4.230000
# Quilassa66                   1                           4.230000
#
#                 Total Purchase Value in Dollars
# SN
# Lisosia93                                 18.96
# Iral74                                    13.62
# Idastidru52                               15.45
# Phyali88                                  10.30
# Saedaiphos46                               8.83
# ...                                         ...
# Aeri84                                     1.61
# Raisty38                                   3.27
# Assjaskan56                                2.96
# Frichirranya75                             4.23
# Quilassa66                                 4.23
#
# [576 rows x 3 columns]
